# %% [markdown]
# <a href="https://colab.research.google.com/github/SRIJANGHOSH03/Sentiment_analysis_social_media/blob/main/Model_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mount Google Drive
# In this step, we connect Google Colab with Google Drive so that we can access our project files and dataset directly from Drive. Once the Drive is mounted, we’ll be able to read and save files just like they’re stored on our computer.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Set your project folder path
project_path = '/content/drive/MyDrive/Superviselearning_project'

# Change working directory
os.chdir(project_path)

# Confirm current working directory
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /content/drive/MyDrive/Superviselearning_project

# %% [markdown]
# ## Load Cleaned Data and TF-IDF Features
# In this section, we load the cleaned dataset and the preprocessed feature files that were saved during the EDA phase.
# These include the TF-IDF matrices (X_train, X_test) and the corresponding sentiment labels (y_train, y_test).

# %%
import joblib, pandas as pd
df = pd.read_csv('data/cleaned_data.csv')
X_train = joblib.load('models/X_train_tfidf.pkl')
X_test = joblib.load('models/X_test_tfidf.pkl')
y_train = joblib.load('models/y_train.pkl')
y_test = joblib.load('models/y_test.pkl')

# %% [markdown]
# # Model Building and Training
# In this step, we load the preprocessed data and TF-IDF feature files saved from the EDA notebook.
# We will train and compare multiple models — Logistic Regression, SVM, Naive Bayes, and BERT — to identify the best-performing sentiment classifier.
